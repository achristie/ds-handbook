# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/seattle.csv", index_col="DATE")
df
# Out:
#                     STATION                                STATION_NAME  PRCP  \
# DATE
# 20140101  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US     0
# 20140102  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US    41
# 20140103  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US    15
# 20140104  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US     0
# 20140105  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US     0
# ...                     ...                                         ...   ...
# 20141227  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US    33
# 20141228  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US    41
# 20141229  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US     0
# 20141230  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US     0
# 20141231  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US     0
#
# ...
